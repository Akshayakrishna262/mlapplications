# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshayakrishna262/mlapplications/blob/main/Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Sample data: a small set of values
data = [5, 7, 7, 8, 9, 10, 10, 10, 11, 12, 11, 11]

# Create the histogram
plt.hist(data, bins=10, edgecolor='black')
plt.title('Simple Histogram Example')
plt.xlabel('Numbers')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
datf = pd.DataFrame({"Season 1": [7,4,5,6,3],
                   "Season 2" : [1,2,8,4,9]})
p = sns.histplot (data = datf)
p.set(xlabel="X Label Value" , ylabel = "Y Label Value")
plt.show()

# %%
import matplotlib.pyplot as plot
import numpy as np
np.random.seed(42)
data= np.random.randint(20,81,1000)
plt.hist(data, bins=15, edgecolor='black', color='skyblue')
plt.title('Histograam of Cancer patients Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of patients')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'semester': ['Sem1', 'Sem1', 'Sem1', 'Sem1', 'Sem1', 'Sem2', 'Sem2', 'Sem2', 'Sem2', 'Sem2'],
    'hours_studied': [7, 9, 4, 17, 23, 68, 92, 81, 72, 10]
}

df = pd.DataFrame(data)

# Adjust the figure size
plt.figure(figsize=(6,6))
sns.boxplot(x='semester', y='hours_studied', data=df)
plt.title('Student Performance')
plt.xlabel('Semester')
plt.ylabel('No. of Hours Studied')
plt.show()

# %%
import pandas as pd
import numpy as np

data = {
    'square_feet_area': [8500, 9600, np.nan, 11250, np.nan, 9550, 14260, np.nan, 13820, 11500],
    'Year_built': [2003, 1976, 2001, np.nan, 1998, 2000, 2006, 1978, 1950, np.nan],
    'over_all_condition': [5, 8, 6, 7, np.nan, 7, np.nan, np.nan, np.nan, np.nan],
    'ready_to_move': ['Yes', 'No', 'Yes', np.nan, 'No', np.nan, 'Yes', 'Yes', 'No', 'Yes'],
    'Sale_price': [200000, 180000, 215000, 250000, 210000, 190000, 230000, 225000, 220000, 240000]
}

df = pd.DataFrame(data)
print("Original Dataframe:")
print(df)

df['square_feet_area'].fillna(df['square_feet_area'].mean(), inplace=True)
df['Year_built'].fillna(df['Year_built'].mean(), inplace=True)
df['over_all_condition'].fillna(df['over_all_condition'].mean(), inplace=True)
df['ready_to_move'].fillna(df['ready_to_move'].mode()[0], inplace=True)

print("\nDataframe after filling missing values:")
print(df)
# Out:
# Original Dataframe:
#    square_feet_area  Year_built  over_all_condition ready_to_move  Sale_price
# 0            8500.0      2003.0                 5.0           Yes      200000
# 1            9600.0      1976.0                 8.0            No      180000
# 2               NaN      2001.0                 6.0           Yes      215000
# 3           11250.0         NaN                 7.0           NaN      250000
# 4               NaN      1998.0                 NaN            No      210000
# 5            9550.0      2000.0                 7.0           NaN      190000
# 6           14260.0      2006.0                 NaN           Yes      230000
# 7               NaN      1978.0                 NaN           Yes      225000
# 8           13820.0      1950.0                 NaN            No      220000
# 9           11500.0         NaN                 NaN           Yes      240000
#
# Dataframe after filling missing values:
# ...
